# %%
# %%bash
#
#
# cat <<EOF > main.c
# #include <stdio.h>
#
# int main() {
#   int i;
#
#   for (i = 0; i < 5; i++){
#   printf("%d\n", i);
# }
# return 0;
# }
# EOF
#
#
# gcc -o output_program main.c
#
#
# ./output_program
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# %%bash
#
#
# cat <<EOF > main.c
# #include <stdio.h>
#
# int main() {
#   int i;
#
#   for (i = 0; i <= 10; i = i + 2) {
#     printf("%d\n", i);
#   }
#   return 0;
# }
# EOF
#
#
# gcc -o output_program main.c
#
#
# ./output_program
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# %%bash
#
#
# cat <<EOF > main.c
# #include <stdio.h>
#
# int main() {
#   int sum = 0;
#   int i;
#
#   for (i = 1; i <= 5; i++) {
#     sum = sum + i;
#   }
#   printf("Sum is %d", sum);
#
#   return 0;
# }
# EOF
#
#
# gcc -o output_program main.c
#
#
# ./output_program
# Out:
# Sum is 15

# %%
# %%bash
#
#
# cat <<EOF > main.c
# #include <stdio.h>
#
# int main() {
#   int i;
#
#   for (i = 5; i > 0; i--) {
#     printf("%d\n", i);
#
#   }
#   return 0;
# }
# EOF
#
#
# gcc -o output_program main.c
#
#
# ./output_program
# Out:
# 5
# 4
# 3
# 2
# 1
