# %%
# %%shell
# g++ -o hello_world -x c++ - <<EOF
#
#
# using namespace std;
#
# int main() {
#     std ::cout << "Hello World!" << endl;
#     return 0;
# }
# EOF
# ./hello_world
# Out:
# <stdin>: In function ‘int main()’:
# <stdin>:6:11: error: ‘cout’ is not a member of ‘std’
# <stdin>:1:1: note: ‘std::cout’ is defined in header ‘<iostream>’; did you forget to ‘#include <iostream>’?
# <stdin>:6:37: error: ‘endl’ was not declared in this scope
# <stdin>:1:1: note: ‘std::endl’ is defined in header ‘<ostream>’; did you forget to ‘#include <ostream>’?
# Hello World!

# %%
# %%shell
# g++ -o hello_world -x c++ - <<EOF
# #include <iostream>
#
#
# using namespace std;
#
# int main() {
#   cout << "Hello World!" << endl;
#   return 0;
# }
# EOF
# ./hello_world
# Out:
# Hello World!

# %%
# %%shell
# g++ -o hello_world -x c++ - <<EOF
# #include <iostream>
#
#
# using namespace std;
#
# int main() {
#   cout << "Hello World!";
# cout << "Have a good day!";
#   return 0;
# }
# EOF
# ./hello_world
# Out:
# Hello World!Have a good day!
